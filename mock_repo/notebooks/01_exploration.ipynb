# %% [markdown]
# # 01 — Exploration
#
# Notebooks live here for **exploration only**. Any code that becomes part of
# the training or serving path must be moved into `src/churn/` and unit-tested.
#
# This file is intentionally empty — it's a placeholder showing where EDA
# notebooks would live in the project structure from Section 3 of the manual.
